# %% [markdown]
# ## Write a function that gets the titles of pages that are linked in one Wikipedia article.
#
# Hints:
# - Use Wikipedia API https://www.mediawiki.org/wiki/API:Main_page, see  https://www.mediawiki.org/wiki/API:Properties, https://www.mediawiki.org/wiki/API:Links#Sample_code for further info
# - use requests library by specifying url and params parameters, e.g. ```requests.get(url = api_url, params = params)```
# - use the `pllimit` to increase the number of links
#
# As an example consider the wikipedia page "University_of_Mannheim".

# %%
import requests 

title = 'University_of_Mannheim'  # title of the Wikipedia page we want to access

api_url = 'https://en.wikipedia.org/w/api.php'  # URL of the API, NOT of the page

# create a 'params' dictionary to automatically encode parameters
params = {'action': 'query',
          'titles': title,
          'prop': 'links', 
          'format': 'json'}

# query the API and parse the resulting JSON
result = requests.get(url = api_url, params = params).json()

# %%
result
# Out:
# {'continue': {'plcontinue': '3910645|0|Alexandra_Burghardt', 'continue': '||'},
#  'query': {'normalized': [{'from': 'University_of_Mannheim',
#     'to': 'University of Mannheim'}],
#   'pages': {'3910645': {'pageid': 3910645,
#     'ns': 0,
#     'title': 'University of Mannheim',
#     'links': [{'ns': 0, 'title': 'AACSB(International)'},
#      {'ns': 0, 'title': 'AIESEC'},
#      {'ns': 0, 'title': 'AStA'},
#      {'ns': 0, 'title': 'Aalto University School of Business'},
#      {'ns': 0,
#       'title': 'Aarhus University, School of Business and Social Sciences'},
#      {'ns': 0, 'title': 'Academic Ranking of World Universities'},
#      {'ns': 0, 'title': 'Academic administration'},
#      {'ns': 0, 'title': 'Academy of Fine Arts, Karlsruhe'},
#      {'ns': 0, 'title': 'Adam Smith School of Economics and Finance'},
#      {'ns': 0, 'title': 'Adolfo Ibáñez University'}]}}}}

# %%
result['query']['pages']
# Out:
# {'3910645': {'pageid': 3910645,
#   'ns': 0,
#   'title': 'University of Mannheim',
#   'links': [{'ns': 0, 'title': 'AACSB(International)'},
#    {'ns': 0, 'title': 'AIESEC'},
#    {'ns': 0, 'title': 'AStA'},
#    {'ns': 0, 'title': 'Aalto University School of Business'},
#    {'ns': 0,
#     'title': 'Aarhus University, School of Business and Social Sciences'},
#    {'ns': 0, 'title': 'Academic Ranking of World Universities'},
#    {'ns': 0, 'title': 'Academic administration'},
#    {'ns': 0, 'title': 'Academy of Fine Arts, Karlsruhe'},
#    {'ns': 0, 'title': 'Adam Smith School of Economics and Finance'},
#    {'ns': 0, 'title': 'Adolfo Ibáñez University'}]}}

# %%
# we want to make this code independent of the current page ID
# therefore, create a list of all pages that were returned
result['query']['pages'].values()
# Out:
# dict_values([{'pageid': 3910645, 'ns': 0, 'title': 'University of Mannheim', 'links': [{'ns': 0, 'title': 'AACSB(International)'}, {'ns': 0, 'title': 'AIESEC'}, {'ns': 0, 'title': 'AStA'}, {'ns': 0, 'title': 'Aalto University School of Business'}, {'ns': 0, 'title': 'Aarhus University, School of Business and Social Sciences'}, {'ns': 0, 'title': 'Academic Ranking of World Universities'}, {'ns': 0, 'title': 'Academic administration'}, {'ns': 0, 'title': 'Academy of Fine Arts, Karlsruhe'}, {'ns': 0, 'title': 'Adam Smith School of Economics and Finance'}, {'ns': 0, 'title': 'Adolfo Ibáñez University'}]}])

# %%
# now select the first (and only) page that was returned
list(result['query']['pages'].values())[0]
# Out:
# {'pageid': 3910645,
#  'ns': 0,
#  'title': 'University of Mannheim',
#  'links': [{'ns': 0, 'title': 'AACSB(International)'},
#   {'ns': 0, 'title': 'AIESEC'},
#   {'ns': 0, 'title': 'AStA'},
#   {'ns': 0, 'title': 'Aalto University School of Business'},
#   {'ns': 0,
#    'title': 'Aarhus University, School of Business and Social Sciences'},
#   {'ns': 0, 'title': 'Academic Ranking of World Universities'},
#   {'ns': 0, 'title': 'Academic administration'},
#   {'ns': 0, 'title': 'Academy of Fine Arts, Karlsruhe'},
#   {'ns': 0, 'title': 'Adam Smith School of Economics and Finance'},
#   {'ns': 0, 'title': 'Adolfo Ibáñez University'}]}

# %%
# get the links from that page
list(result['query']['pages'].values())[0]['links']
# Out:
# [{'ns': 0, 'title': 'AACSB(International)'},
#  {'ns': 0, 'title': 'AIESEC'},
#  {'ns': 0, 'title': 'AStA'},
#  {'ns': 0, 'title': 'Aalto University School of Business'},
#  {'ns': 0,
#   'title': 'Aarhus University, School of Business and Social Sciences'},
#  {'ns': 0, 'title': 'Academic Ranking of World Universities'},
#  {'ns': 0, 'title': 'Academic administration'},
#  {'ns': 0, 'title': 'Academy of Fine Arts, Karlsruhe'},
#  {'ns': 0, 'title': 'Adam Smith School of Economics and Finance'},
#  {'ns': 0, 'title': 'Adolfo Ibáñez University'}]

# %%
# print all the titles
for link in list(result['query']['pages'].values())[0]['links']:
    print(link['title'])
# Out:
# AACSB(International)
# AIESEC
# AStA
# Aalto University School of Business
# Aarhus University, School of Business and Social Sciences
# Academic Ranking of World Universities
# Academic administration
# Academy of Fine Arts, Karlsruhe
# Adam Smith School of Economics and Finance
# Adolfo Ibáñez University

# %% [markdown]
# Now that this seems to work, let's set the page_limit to 500 results.

# %%
import requests 
title = 'University_of_Mannheim'
page_limit = 500

api_url = 'https://en.wikipedia.org/w/api.php' 

params = {'action': 'query',
          'titles': title,
          'prop': 'links', 
          'format': 'json',
          'pllimit': page_limit}

result = requests.get(url = api_url, params = params).json()

# %%
for link in list(result['query']['pages'].values())[0]['links']:
    print(link['title'])
# Out:
# AACSB(International)
# AIESEC
# AStA
# Aalto University School of Business
# Aarhus University, School of Business and Social Sciences
# Academic Ranking of World Universities
# Academic administration
# Academy of Fine Arts, Karlsruhe
# Adam Smith School of Economics and Finance
# Adolfo Ibáñez University
# Alexandra Burghardt
# Alliance Manchester Business School
# Americas
# Amnesty International
# Antai College of Economics and Management
# Asian people
# Association des États Généraux des Étudiants de l'Europe
# Association of MBAs
# Association to Advance Collegiate Schools of Business
# Aston University
# Audencia Business School
# Auschwitz concentration camp
# Autonomous University of Barcelona
# Axel Dreher
# BI Norwegian Business School
# Baden-Württemberg
# Baden-Württemberg Cooperative State University
# Bauhaus University, Weimar
# Bavaria
# Bayes Business School
# Berlin
# Berlin University of the Arts
# Biberach University of Applied Sciences
# Bielefeld University
# Birmingham Business School (University of Birmingham)
# Bloomberg Businessweek
# Blue
# Brandenburg
# Brandenburg University of Technology
# Bremen (state)
# Bruno Sälzer
# Bundeswehr University Munich
# Business administration
# CFA Institute
# Catacombs
# Catholic University of Applied Sciences Freiburg
# Catholic University of Eichstätt-Ingolstadt
# Católica Lisbon School of Business & Economics
# Centre for European Economic Research
# Chancellor (education)
# Charles III University of Madrid
# Charles Theodore, Elector of Bavaria
# Chemnitz University of Technology
# Christoph M. Schmidt
# Claus E. Heinrich
# Claus Wellenreuther
# Clausthal University of Technology
# Clemens Fuest
# College and university rankings
# Computer science
# Congress
# Constructor University
# Copenhagen Business School
# Council on Business & Society
# Cranfield School of Management
# Cécile Pieper
# Demographics of Germany
# Deutsche Bundesbank
# Deutsche Forschungsgemeinschaft
# Docent
# Doctorate
# Durham University Business School
# EDHEC
# EFMD Quality Improvement System
# ESADE Business School
# ESMT Berlin
# ESSEC Business School
# Eberhard Gothein
# Eduard Gaugler
# Education in Germany
# Eduniversal
# Emlyon Business School
# Erasmus University Rotterdam
# Ernst-Ludwig von Thadden
# Escada
# Escola de Administração de Empresas de São Paulo
# Esslingen University of Applied Sciences
# Ethnic groups of Africa
# European Network for Training Economic Research
# European Quality Improvement System
# European Union
# European University Viadrina
# European ethnic groups
# Excelia Group
# FGV-EAESP
# Federal Ministry of Education and Research (Germany)
# Financial Times
# Forbes
# Frankfurt School of Finance & Management
# Free University of Berlin
# Freiberg University of Mining and Technology
# Fudan University
# Fundação Getúlio Vargas
# GESIS – Leibniz Institute for the Social Sciences
# Geographic coordinate system
# Gerd Roellecke
# Gerhard Zeitel
# German Excellence Universities
# German Universities Excellence Initiative
# German University of Administrative Sciences Speyer
# Gitanas Nausėda
# Goethe University Frankfurt
# Gothenburg School of Business, Economics and Law
# Gottfried Wilhelm Leibniz Prize
# Graduate School of Economic and Social Sciences
# Grenoble école de management
# Gustav Siewerth Academy
# HEC Montreal
# HEC Paris
# HafenCity University Hamburg
# Hamburg
# Hamburg University of Technology
# Hanken School of Economics
# Hans-Martin Pawlowski
# Hans-Peter Wild
# Hans-Werner Sinn
# Hans-Wolfgang Arndt
# Hans Meuer
# Heidelberg University
# Heilbronn University
# Heinrich Chantraine
# Heinrich Heine University Düsseldorf
# Heinz König
# Helmut Schmidt University
# Henley Business School
# Henning Kagermann
# Hesse
# Hochschule Furtwangen University
# Hochschule Konstanz
# Hochschule der Medien
# Hochschule für Kirchenmusik Heidelberg
# Hochschule für Musik Freiburg
# Hong Kong Baptist University
# Horst Siebert
# Hugo Boss
# Hult International Business School
# Humanities
# Humboldt University of Berlin
# IAAF World Relays
# IAE Universidad Austral
# ICN Graduate Business School
# IDS – Institute of German Language
# IESE Business School
# IE Business School
# IMU – Institute for Market-oriented Management
# INCAE Business School
# INSEAD
# ISBN (identifier)
# ISSN (identifier)
# IfM – Small and Medium Sized Companies and Entrepreneurship
# Ifo Institute for Economic Research
# Imperial College Business School
# Indian Institute of Management Calcutta
# Indian Institute of Management Indore
# Indian School of Business
# Information systems
# Insper
# Institute for Market-oriented Management
# Instituto Tecnológico Autónomo de México
# Instituto de Estudios Superiores de Administración
# International Association of Universities
# International Business Education Alliance
# International Institute for Management Development
# International Supercomputing Conference
# Isabel Schnabel
# IÉSEG School of Management
# Jens Weidmann
# Jesuit Church, Mannheim
# Joachim Weickert
# KEDGE Business School
# Karlshochschule International University
# Karlsruhe Institute of Technology
# Karlsruhe University of Applied Sciences
# Karlsruhe University of Arts and Design
# Keio University
# Kiel University
# Knut Borchardt
# Kozminski University
# Lancaster University Management School
# Latin
# Lee Kong Chian School of Business
# Leeds University Business School
# Leibniz University Hannover
# Leipzig University
# Leuphana University of Lüneburg
# List of University of Mannheim people
# List of business schools in Europe
# List of universities in Germany
# Lithuania
# London Business School
# Loughborough University
# Lower Saxony
# Ludwig Eid
# Ludwig Maximilian University of Munich
# MAZEM – Mannheim Center for Empirical Multilingual Research
# Maastricht University
# Malaika Mihambo
# Manchester Metropolitan University
# Mannheim
# Mannheim Business School
# Mannheim Centre for Competition and Innovation
# Mannheim Centre for European Social Research
# Mannheim Forum
# Mannheim Graduate School for Economics and Social Sciences
# Mannheim Observatory
# Mannheim Palace
# Mannheim Palace Church
# Mannheim Schneckenhof
# Mannheim School of Computer Science and Mathematics
# Mannheim School of Humanities
# Mannheim School of Law and Economics
# Mannheim School of Social Sciences
# Mannheim University Library
# Mannheim University of Applied Sciences
# Martin Luther University Halle-Wittenberg
# Master's degree
# Mecklenburg-Vorpommern
# Million
# Model United Nations
# Monash University
# Monterrey Institute of Technology and Higher Education
# Montpellier Business School
# NEOMA Business School
# NSDAP
# Newcastle University
# North Rhine-Westphalia
# Nova School of Business and Economics
# Nürtingen-Geislingen University of Applied Science
# Open University Business School
# Osnabrück University
# Otto-Selz-Institute of Applied Psychology
# Otto Beck
# Otto H. Jacobs
# Otto Selz
# Otto von Guericke University Magdeburg
# Paderborn University
# Palais Bretzenheim
# Pedagogy
# Peter Frankenberg
# Pforzheim University of Applied Sciences
# Pontificia Universidad Católica del Perú
# Popakademie Baden-Württemberg
# Postgraduate education
# Prague University of Economics and Business
# Protestant University for Applied Sciences Freiburg
# Public University
# Public university
# QS World University Rankings
# QUT Business School
# Quadrangle (architecture)
# RWI Essen
# RWTH Aachen University
# Ravensburg University of Cooperative Education
# Rector (academia)
# Refrain
# Research university
# Rhein-Neckar
# Rhine
# Rhineland-Palatinate
# Robert Heinrich Wagner
# Roman Inderst
# Rottenburg University of Applied Forest Sciences
# Ruhr University Bochum
# SAP AG
# SDA Bocconi School of Management
# Saarland
# Saarland University
# Saxony
# Saxony-Anhalt
# Schleswig-Holstein
# School colors
# Seal (emblem)
# Senate
# Social science
# Social sciences
# Stefan Lippe
# Strathclyde Business School
# Stuttgart Technology University of Applied Sciences
# Sun Yat-sen University
# Swiss Re
# Söhne Mannheims
# TUM School of Management
# TU Dresden
# Technical University of Berlin
# Technical University of Braunschweig
# Technical University of Dortmund
# Technical University of Munich
# Technische Universität Darmstadt
# Technische Universität Ilmenau
# Telfer School of Management
# Thammasat University
# The American University in Cairo
# The Economist
# The Holocaust
# The Palais Bretzenheim
# Thuringia
# Tilburg University
# Times Higher Education World University Rankings
# Tongji University
# Toulouse 1 University Capitole
# Toulouse Business School
# Triple accreditation
# UCI World Championships
# UNICEF
# Ukrainian Free University
# Undergraduate education
# University College Dublin
# University College London
# University Council
# University of Applied Sciences Offenburg
# University of Applied Sciences Ravensburg-Weingarten
# University of Auckland
# University of Augsburg
# University of Bamberg
# University of Bayreuth
# University of Bonn
# University of Bradford School of Management
# University of Bremen
# University of Canterbury
# University of Cape Town Graduate School of Business
# University of Cologne
# University of Duisburg-Essen
# University of Edinburgh Business School
# University of Erfurt
# University of Erlangen–Nuremberg
# University of Exeter Business School
# University of Flensburg
# University of Freiburg
# University of Giessen
# University of Greifswald
# University of Göttingen
# University of Hagen
# University of Hamburg
# University of Hildesheim
# University of Hohenheim
# University of Ingolstadt
# University of International Business and Economics (Beijing)
# University of Jena
# University of Kaiserslautern-Landau
# University of Kassel
# University of Koblenz
# University of Konstanz
# University of Liverpool
# University of Los Andes (Colombia)
# University of Lübeck
# University of Mainz
# University of Mannheim Business School
# University of Marburg
# University of Münster
# University of Oldenburg
# University of Passau
# University of Potsdam
# University of Regensburg
# University of Rostock
# University of Sheffield Management School
# University of Siegen
# University of South Carolina
# University of St. Gallen
# University of Stellenbosch Business School
# University of Stockholm
# University of Stuttgart
# University of Trier
# University of Tübingen
# University of Ulm
# University of Vechta
# University of Waikato
# University of Wuppertal
# University of Würzburg
# Université libre de Bruxelles
# Victoria University of Wellington
# Vienna University of Economics and Business
# Vlerick Business School
# Waiver
# Warwick Business School
# Warwick University
# Wild (company)
# Witten/Herdecke University
# World War II
# Wuhan University School of Economics and Management
# Xiamen University
# ZEW
# Zentrum für Europäische Wirtschaftsforschung
# Zeppelin University
# Zhejiang University
# École supérieure des sciences commerciales d'Angers
# Wikipedia:Citation needed
# Wikipedia:Link rot
# Wikipedia:Manual of Style/Words to watch
# File:SchlossMannheim-Pano-130616.jpg
# Template:Cite book
# Template:Council on Business & Society
# Template:Country data EU
# Template:European Network for Training Economic Research
# Template:International Business Education Alliance
# Template:Triple accreditation
# Template:Universities and colleges in Baden-Württemberg
# Template:Universities in Germany
# Template:University of Mannheim
# Template talk:Council on Business & Society
# Template talk:European Network for Training Economic Research
# Template talk:International Business Education Alliance
# Template talk:Triple accreditation
# Template talk:Universities and colleges in Baden-Württemberg
# Template talk:Universities in Germany
# Template talk:University of Mannheim
# Help:Authority control
# Category:Articles with BNF identifiers
# Category:Articles with BNFdata identifiers
# Category:Articles with GND identifiers
# Category:Articles with ISNI identifiers
# Category:Articles with J9U identifiers
# Category:Articles with LCCN identifiers
# Category:Articles with NKC identifiers
# Category:Articles with NLA identifiers
# Category:Articles with SUDOC identifiers
# Category:Articles with VIAF identifiers
# Category:Articles with VcBA identifiers
# Category:Articles with dead external links from October 2022
# Category:Articles with specifically marked weasel-worded phrases from July 2023
# Category:Articles with unsourced statements from June 2020
# Category:CS1 maint: location missing publisher
# Category:Universität Mannheim
# Category:Use dmy dates from February 2023
# Portal:Germany

# %% [markdown]
# ## Get the extract of a Wikipedia page

# %% [markdown]
# Hint: for that you would need to use a property called 'extracts'. You would also like to set additional parameters ```exintro``` and ```explaintext``` to be ```True```

# %%
api_url = 'https://en.wikipedia.org/w/api.php' 

params ={'action': 'query',
         'titles': title,
         'prop': 'extracts',  # this time, we would like to get the extracts
         'exintro': True,
         'explaintext': True,
         'format': 'json'}

# perform the request
request = requests.get(url = api_url, params = params).json()

# similarly to before, get the resulting pages
pages = request['query']['pages']
pages
# Out:
# {'3910645': {'pageid': 3910645,
#   'ns': 0,
#   'title': 'University of Mannheim',
#   'extract': "The University of Mannheim (German: Universität Mannheim), abbreviated UMA, is a public research university in Mannheim, Baden-Württemberg, Germany. Founded in 1967, the university has its origins in the Palatine Academy of Sciences, which was established by Elector Carl Theodor at Mannheim Palace in 1763, as well as the Handelshochschule (Commercial College Mannheim), which was founded in 1907. The university is regularly ranked as one of Germany's best business school as well as a leading institution in economics and social sciences.The university offers undergraduate, graduate and doctoral  programs in business administration, economics, law, social sciences, humanities, mathematics, computer science and information systems. The university's campus is located in the city center of Mannheim and its main campus is in the Mannheim Palace. In the academic year 2020/2021 the university had 11,640 full-time students, 1600 academic staff, with 194 professors, and a total income of around €121 million. It is organized into five schools and two graduate colleges.\n\n"}}

# %%
# get the extract of the first (and only) page that was returned
page_id = list(pages.keys())[0]
pages[page_id]['extract']
# Out:
# "The University of Mannheim (German: Universität Mannheim), abbreviated UMA, is a public research university in Mannheim, Baden-Württemberg, Germany. Founded in 1967, the university has its origins in the Palatine Academy of Sciences, which was established by Elector Carl Theodor at Mannheim Palace in 1763, as well as the Handelshochschule (Commercial College Mannheim), which was founded in 1907. The university is regularly ranked as one of Germany's best business school as well as a leading institution in economics and social sciences.The university offers undergraduate, graduate and doctoral  programs in business administration, economics, law, social sciences, humanities, mathematics, computer science and information systems. The university's campus is located in the city center of Mannheim and its main campus is in the Mannheim Palace. In the academic year 2020/2021 the university had 11,640 full-time students, 1600 academic staff, with 194 professors, and a total income of around €121 million. It is organized into five schools and two graduate colleges.\n\n"

# %% [markdown]
# ## Create a recipe shopping list

# %% [markdown]
# Assume that you want to prepare several meals, e.g. [Spaghetti Bolognese](https://www.chefkoch.de/rezepte/1618631269095146/Spaghetti-Bolognese.html) and [Yvonnes Wikingertopf](https://www.chefkoch.de/rezepte/1738671282836420/Yvonnes-Wikingertopf.html). Use Chefkoch API to create a shopping list of ingridients that you will need given a list of recipe IDs (aggregate multiple occurences of the same ingredient into one). You can use Chefkoch API by calling https://api.chefkoch.de/v2/recipes/ID, where ID is a corresponding ID, e.g. 1618631269095146

# %%
api_url = "https://api.chefkoch.de/v2/recipes/"

# %%
# perform the request to chefkoch.de and parse the result
s = requests.get(api_url + '1618631269095146').json()

# %%
s
# Out:
# {'id': '1618631269095146',
#  'type': 0,
#  'title': 'Spaghetti Bolognese',
#  'subtitle': 'Bologneser Art - Jamie und Jessy vereint',
#  'owner': {'id': 'dc19e9d50d1d20cb45e2b832bc745157',
#   'username': 'jessy70',
#   'rank': 4,
#   'role': 'user',
#   'hasAvatar': True,
#   'hasPaid': False,
#   'deleted': False,
#   'avatarImageUrlTemplate': 'https://img.chefkoch-cdn.de/images/<format>/ck.de/user/dc19e9d50d1d20cb45e2b832bc745157.jpg',
#   'isVerified': False,
#   'displayName': 'jessy70'},
#  'rating': {'rating': 4.55, 'numVotes': 121},
#  'difficulty': 1,
#  'hasImage': True,
#  'hasVideo': True,
#  'previewImageId': '1287628',
#  'previewImageOwner': {'id': '72fa02c53153ec3503ab57735a3f1c00',
#   'username': 'TZ89',
#   'rank': 5,
#   'role': 'user',
#   'hasAvatar': True,
#   'hasPaid': False,
#   'deleted': False,
#   'avatarImageUrlTemplate': 'https://img.chefkoch-cdn.de/images/<format>/ck.de/user/72fa02c53153ec3503ab57735a3f1c00.jpg',
#   'isVerified': False,
#   'displayName': 'TZ89'},
#  'preparationTime': 30,
#  'isSubmitted': True,
#  'isRejected': False,
#  'createdAt': '2010-03-20T17:42:02+01:00',
#  'imageCount': 54,
#  'editor': {'id': '651ed30d358ecb8b4ffdba20e5cb12e7',
#   'username': 'elschen',
#   'rank': 9,
#   'role': 'moderator',
#   'hasAvatar': True,
#   'hasPaid': True,
#   'deleted': False,
#   'avatarImageUrlTemplate': 'https://img.chefkoch-cdn.de/images/<format>/ck.de/user/651ed30d358ecb8b4ffdba20e5cb12e7.jpg',
#   'isVerified': False,
#   'displayName': 'elschen'},
#  'submissionDate': '2010-01-09T15:25:30+01:00',
#  'isPremium': False,
#  'status': 99,
#  'slug': 'Spaghetti-Bolognese',
#  'previewImageUrlTemplate': 'https://img.chefkoch-cdn.de/rezepte/1618631269095146/bilder/1287628/<format>/spaghetti-bolognese.jpg',
#  'previewImageCredits': None,
#  'isPlus': False,
#  'additionalDescription': '',
#  'source': None,
#  'servings': 6,
#  'kCalories': 0,
#  'nutrition': None,
#  'instructions': 'In einem großen Topf den Speck  und den Rosmarin in Olivenöl goldgelb anbraten. Zwiebeln und Knoblauch zugeben und 3 Minuten unter Rühren anschmoren. Dann das Hackfleisch zugeben und anbraten. Danach den Wein zugeben und die Flüssigkeit etwas reduzieren lassen. Dann den Oregano, die Möhren und alle Tomaten und n.B. etwas Tomatenmark zugeben. Mit den Gewürzen, außer dem Basilikum, gut abschmecken, nochmals aufkochen, die Hitze fast ganz runter nehmen, Deckel drauf und 1,5 bis 2 Stunden leise köcheln lassen. \n\nKurz vor Ende die Nudeln nach Packungsanleitung al dente kochen. In die fertige Sauce das frisch zerkleinerte Basilikum geben und mit frisch geriebenem Parmesan und Rotwein servieren.\n\nEin grüner Salat dazu schmeckt auch prima.',
#  'miscellaneousText': '',
#  'ingredientsText': '',
#  'tags': ['Pasta', 'Nudeln'],
#  'fullTags': [{'id': 18, 'name': 'Gemüse'},
#   {'id': 21, 'name': 'Hauptspeise'},
#   {'id': 22, 'name': 'Rind'},
#   {'id': 24, 'name': 'Nudeln'},
#   {'id': 31, 'name': 'Pasta'},
#   {'id': 50, 'name': 'einfach'},
#   {'id': 144, 'name': 'gekocht'}],
#  'viewCount': 1909344,
#  'cookingTime': 135,
#  'restingTime': 0,
#  'totalTime': 165,
#  'ingredientGroups': [{'header': ' ',
#    'ingredients': [{'id': '6290718',
#      'name': 'Rinderhackfleisch',
#      'unit': 'kg',
#      'unitId': '28',
#      'amount': 1.0,
#      'isBasic': False,
#      'usageInfo': '',
#      'url': None,
#      'foodId': '13796',
#      'productGroup': 'Fleisch und Wurstwaren',
#      'blsKey': 'U010100',
#      'previewImageUrlTemplate': 'https://img.chefkoch-cdn.de/images/<format>/assets/v2/img/food/AS_383250176.png'},
#     {'id': '6290719',
#      'name': 'Speck',
#      'unit': 'g',
#      'unitId': '3',
#      'amount': 250.0,
#      'isBasic': False,
#      'usageInfo': ', in kleinen Würfelchen',
#      'url': None,
#      'foodId': '689',
#      'productGroup': 'Fleisch und Wurstwaren',
#      'blsKey': 'W411000',
#      'previewImageUrlTemplate': 'https://img.chefkoch-cdn.de/images/<format>/assets/v2/img/food/AS_604313966.png'},
#     {'id': '6290720',
#      'name': 'Tomate(n)',
#      'unit': 'Glas',
#      'unitId': '31',
#      'amount': 1.0,
#      'isBasic': False,
#      'usageInfo': ', getrocknete, abgegossen und fein gehackt',
#      'url': 'https://www.chefkoch.de/magazin/artikel/46,0/Chefkoch/Tomaten-Pflanzen-ernten-tolle-Gerichte-entdecken.html',
#      'foodId': '25',
#      'productGroup': 'Obst,  Gemüse und Kräuter',
#      'blsKey': 'G560000',
#      'previewImageUrlTemplate': 'https://img.chefkoch-cdn.de/images/<format>/assets/v2/img/food/AS_70775723.png'},
#     {'id': '6290721',
#      'name': 'Zwiebel(n)',
#      'unit': 'große',
#      'unitId': '21',
#      'amount': 1.0,
#      'isBasic': False,
#      'usageInfo': ', oder 2 kleinere, fein gehackt',
#      'url': None,
#      'foodId': '29',
#      'productGroup': 'Obst,  Gemüse und Kräuter',
#      'blsKey': 'G480000',
#      'previewImageUrlTemplate': 'https://img.chefkoch-cdn.de/images/<format>/assets/v2/img/food/AS_385537967.png'},
#     {'id': '6290722',
#      'name': 'Knoblauchzehe(n)',
#      'unit': '',
#      'unitId': '9',
#      'amount': 3.0,
#      'isBasic': False,
#      'usageInfo': ', fein gehackt',
#      'url': 'https://www.chefkoch.de/magazin/artikel/29,0/Chefkoch/Knoblauch.html',
#      'foodId': '5675',
#      'productGroup': 'Obst,  Gemüse und Kräuter',
#      'blsKey': 'G490000',
#      'previewImageUrlTemplate': 'https://img.chefkoch-cdn.de/images/<format>/assets/v2/img/food/AS_42343143.png'},
#     {'id': '6290723',
#      'name': 'Rosmarin',
#      'unit': 'Handvoll',
#      'unitId': '48',
#      'amount': 1.0,
#      'isBasic': False,
#      'usageInfo': ', die Blätter abgezupft und fein gehackt',
#      'url': None,
#      'foodId': '266',
#      'productGroup': 'Obst,  Gemüse und Kräuter',
#      'blsKey': 'G078000',
#      'previewImageUrlTemplate': 'https://img.chefkoch-cdn.de/images/<format>/assets/v2/img/food/AS_68358825.png'},
#     {'id': '6290724',
#      'name': 'Olivenöl',
#      'unit': '',
#      'unitId': '9',
#      'amount': 0.0,
#      'isBasic': False,
#      'usageInfo': '',
#      'url': 'https://www.chefkoch.de/magazin/artikel/66,0/Chefkoch/Olivenoel-und-die-richtige-Verwendung-in-der-Kueche.html',
#      'foodId': '3393',
#      'productGroup': 'Essig,  Öl und Soßen',
#      'blsKey': 'Q120000',
#      'previewImageUrlTemplate': 'https://img.chefkoch-cdn.de/images/<format>/assets/v2/img/food/AS_124729332.png'},
#     {'id': '6290725',
#      'name': 'Rotwein',
#      'unit': 'Gläser',
#      'unitId': '93',
#      'amount': 2.0,
#      'isBasic': False,
#      'usageInfo': '',
#      'url': None,
#      'foodId': '8793',
#      'productGroup': 'Getränke',
#      'blsKey': 'P200000',
#      'previewImageUrlTemplate': 'https://img.chefkoch-cdn.de/images/<format>/assets/v2/img/food/AS_578761334.png'},
#     {'id': '6290726',
#      'name': 'Tomate(n)',
#      'unit': 'kl. Dose/n',
#      'unitId': '104',
#      'amount': 3.0,
#      'isBasic': False,
#      'usageInfo': ', gehackt',
#      'url': 'https://www.chefkoch.de/magazin/artikel/46,0/Chefkoch/Tomaten-Pflanzen-ernten-tolle-Gerichte-entdecken.html',
#      'foodId': '25',
#      'productGroup': 'Obst,  Gemüse und Kräuter',
#      'blsKey': 'G560000',
#      'previewImageUrlTemplate': 'https://img.chefkoch-cdn.de/images/<format>/assets/v2/img/food/AS_70775723.png'},
#     {'id': '6290727',
#      'name': 'Meersalz',
#      'unit': '',
#      'unitId': '9',
#      'amount': 0.0,
#      'isBasic': False,
#      'usageInfo': '',
#      'url': 'https://www.chefkoch.de/magazin/artikel/1054,2/Chefkoch/Salz-unser-wichtigstes-Gewuerz.html',
#      'foodId': '405',
#      'productGroup': 'Salz und Zucker',
#      'blsKey': 'R112000',
#      'previewImageUrlTemplate': 'https://img.chefkoch-cdn.de/images/<format>/assets/v2/img/food/AS_144425698.png'},
#     {'id': '6290728',
#      'name': 'Pfeffer',
#      'unit': '',
#      'unitId': '9',
#      'amount': 0.0,
#      'isBasic': False,
#      'usageInfo': ', frisch gemahlen',
#      'url': None,
#      'foodId': '20',
#      'productGroup': 'Gewürze',
#      'blsKey': 'R258000',
#      'previewImageUrlTemplate': 'https://img.chefkoch-cdn.de/images/<format>/assets/v2/img/food/AS_195161277.png'},
#     {'id': '6290729',
#      'name': 'Möhre(n)',
#      'unit': 'große',
#      'unitId': '21',
#      'amount': 4.0,
#      'isBasic': False,
#      'usageInfo': ', in kleinen Stückchen',
#      'url': 'https://www.chefkoch.de/magazin/artikel/2737,0/Chefkoch/Moehren-knackige-und-gesunde-Wurzeln-fuer-alle-Faelle.html',
#      'foodId': '24',
#      'productGroup': 'Obst,  Gemüse und Kräuter',
#      'blsKey': 'G620100',
#      'previewImageUrlTemplate': 'https://img.chefkoch-cdn.de/images/<format>/assets/v2/img/food/AS_53111552.png'},
#     {'id': '6290730',
#      'name': 'Basilikum',
#      'unit': 'Handvoll',
#      'unitId': '48',
#      'amount': 1.0,
#      'isBasic': False,
#      'usageInfo': '',
#      'url': None,
#      'foodId': '66',
#      'productGroup': 'Obst,  Gemüse und Kräuter',
#      'blsKey': 'G061000',
#      'previewImageUrlTemplate': 'https://img.chefkoch-cdn.de/images/<format>/assets/v2/img/food/US_bLWVqWOUfI4.png'},
#     {'id': '6290731',
#      'name': 'Worcestersauce',
#      'unit': '',
#      'unitId': '9',
#      'amount': 0.0,
#      'isBasic': False,
#      'usageInfo': '',
#      'url': None,
#      'foodId': '10632',
#      'productGroup': 'Essig,  Öl und Soßen',
#      'blsKey': 'R149200',
#      'previewImageUrlTemplate': ''},
#     {'id': '6290732',
#      'name': 'Lorbeerblätter',
#      'unit': '',
#      'unitId': '9',
#      'amount': 1.0,
#      'isBasic': False,
#      'usageInfo': '',
#      'url': None,
#      'foodId': '162',
#      'productGroup': 'Gewürze',
#      'blsKey': 'H120100',
#      'previewImageUrlTemplate': 'https://img.chefkoch-cdn.de/images/<format>/assets/v2/img/food/AS_219962549.png'},
#     {'id': '6290733',
#      'name': 'Oregano',
#      'unit': 'TL, gestr.',
#      'unitId': '164',
#      'amount': 2.0,
#      'isBasic': False,
#      'usageInfo': '',
#      'url': None,
#      'foodId': '457',
#      'productGroup': 'Obst,  Gemüse und Kräuter',
#      'blsKey': 'G076000',
#      'previewImageUrlTemplate': 'https://img.chefkoch-cdn.de/images/<format>/assets/v2/img/food/AS_111141991.png'},
#     {'id': '6290734',
#      'name': 'Tomatenmark',
#      'unit': 'n. B.',
#      'unitId': '7',
#      'amount': 0.0,
#      'isBasic': False,
#      'usageInfo': '',
#      'url': None,
#      'foodId': '80',
#      'productGroup': 'Konserven und Fertiggerichte',
#      'blsKey': 'R160000',
#      'previewImageUrlTemplate': 'https://img.chefkoch-cdn.de/images/<format>/assets/v2/img/food/AS_95095072.png'},
#     {'id': '6290735',
#      'name': 'Spaghetti',
#      'unit': 'kg',
#      'unitId': '28',
#      'amount': 1.0,
#      'isBasic': False,
#      'usageInfo': '',
#      'url': None,
#      'foodId': '6059',
#      'productGroup': 'Nudeln,  Reis & Co.',
#      'blsKey': 'E404000',
#      'previewImageUrlTemplate': 'https://img.chefkoch-cdn.de/images/<format>/assets/v2/img/food/AS_622563903.png'}]}],
#  'categoryIds': ['81', '164', '14', '13', '114'],
#  'recipeVideoId': '3497',
#  'isIndexable': True,
#  'affiliateContent': '',
#  'metaTitle': '',
#  'metaDescription': '',
#  'siteUrl': 'https://www.chefkoch.de/rezepte/1618631269095146/Spaghetti-Bolognese.html'}

# %%
s.keys()  # only the keys of the dictionary
# Out:
# dict_keys(['id', 'type', 'title', 'subtitle', 'owner', 'rating', 'difficulty', 'hasImage', 'hasVideo', 'previewImageId', 'previewImageOwner', 'preparationTime', 'isSubmitted', 'isRejected', 'createdAt', 'imageCount', 'editor', 'submissionDate', 'isPremium', 'status', 'slug', 'previewImageUrlTemplate', 'previewImageCredits', 'isPlus', 'additionalDescription', 'source', 'servings', 'kCalories', 'nutrition', 'instructions', 'miscellaneousText', 'ingredientsText', 'tags', 'fullTags', 'viewCount', 'cookingTime', 'restingTime', 'totalTime', 'ingredientGroups', 'categoryIds', 'recipeVideoId', 'isIndexable', 'affiliateContent', 'metaTitle', 'metaDescription', 'siteUrl'])

# %%
s['ingredientGroups']  # this is the ingredients
# Out:
# [{'header': ' ',
#   'ingredients': [{'id': '6290718',
#     'name': 'Rinderhackfleisch',
#     'unit': 'kg',
#     'unitId': '28',
#     'amount': 1.0,
#     'isBasic': False,
#     'usageInfo': '',
#     'url': None,
#     'foodId': '13796',
#     'productGroup': 'Fleisch und Wurstwaren',
#     'blsKey': 'U010100',
#     'previewImageUrlTemplate': 'https://img.chefkoch-cdn.de/images/<format>/assets/v2/img/food/AS_383250176.png'},
#    {'id': '6290719',
#     'name': 'Speck',
#     'unit': 'g',
#     'unitId': '3',
#     'amount': 250.0,
#     'isBasic': False,
#     'usageInfo': ', in kleinen Würfelchen',
#     'url': None,
#     'foodId': '689',
#     'productGroup': 'Fleisch und Wurstwaren',
#     'blsKey': 'W411000',
#     'previewImageUrlTemplate': 'https://img.chefkoch-cdn.de/images/<format>/assets/v2/img/food/AS_604313966.png'},
#    {'id': '6290720',
#     'name': 'Tomate(n)',
#     'unit': 'Glas',
#     'unitId': '31',
#     'amount': 1.0,
#     'isBasic': False,
#     'usageInfo': ', getrocknete, abgegossen und fein gehackt',
#     'url': 'https://www.chefkoch.de/magazin/artikel/46,0/Chefkoch/Tomaten-Pflanzen-ernten-tolle-Gerichte-entdecken.html',
#     'foodId': '25',
#     'productGroup': 'Obst,  Gemüse und Kräuter',
#     'blsKey': 'G560000',
#     'previewImageUrlTemplate': 'https://img.chefkoch-cdn.de/images/<format>/assets/v2/img/food/AS_70775723.png'},
#    {'id': '6290721',
#     'name': 'Zwiebel(n)',
#     'unit': 'große',
#     'unitId': '21',
#     'amount': 1.0,
#     'isBasic': False,
#     'usageInfo': ', oder 2 kleinere, fein gehackt',
#     'url': None,
#     'foodId': '29',
#     'productGroup': 'Obst,  Gemüse und Kräuter',
#     'blsKey': 'G480000',
#     'previewImageUrlTemplate': 'https://img.chefkoch-cdn.de/images/<format>/assets/v2/img/food/AS_385537967.png'},
#    {'id': '6290722',
#     'name': 'Knoblauchzehe(n)',
#     'unit': '',
#     'unitId': '9',
#     'amount': 3.0,
#     'isBasic': False,
#     'usageInfo': ', fein gehackt',
#     'url': 'https://www.chefkoch.de/magazin/artikel/29,0/Chefkoch/Knoblauch.html',
#     'foodId': '5675',
#     'productGroup': 'Obst,  Gemüse und Kräuter',
#     'blsKey': 'G490000',
#     'previewImageUrlTemplate': 'https://img.chefkoch-cdn.de/images/<format>/assets/v2/img/food/AS_42343143.png'},
#    {'id': '6290723',
#     'name': 'Rosmarin',
#     'unit': 'Handvoll',
#     'unitId': '48',
#     'amount': 1.0,
#     'isBasic': False,
#     'usageInfo': ', die Blätter abgezupft und fein gehackt',
#     'url': None,
#     'foodId': '266',
#     'productGroup': 'Obst,  Gemüse und Kräuter',
#     'blsKey': 'G078000',
#     'previewImageUrlTemplate': 'https://img.chefkoch-cdn.de/images/<format>/assets/v2/img/food/AS_68358825.png'},
#    {'id': '6290724',
#     'name': 'Olivenöl',
#     'unit': '',
#     'unitId': '9',
#     'amount': 0.0,
#     'isBasic': False,
#     'usageInfo': '',
#     'url': 'https://www.chefkoch.de/magazin/artikel/66,0/Chefkoch/Olivenoel-und-die-richtige-Verwendung-in-der-Kueche.html',
#     'foodId': '3393',
#     'productGroup': 'Essig,  Öl und Soßen',
#     'blsKey': 'Q120000',
#     'previewImageUrlTemplate': 'https://img.chefkoch-cdn.de/images/<format>/assets/v2/img/food/AS_124729332.png'},
#    {'id': '6290725',
#     'name': 'Rotwein',
#     'unit': 'Gläser',
#     'unitId': '93',
#     'amount': 2.0,
#     'isBasic': False,
#     'usageInfo': '',
#     'url': None,
#     'foodId': '8793',
#     'productGroup': 'Getränke',
#     'blsKey': 'P200000',
#     'previewImageUrlTemplate': 'https://img.chefkoch-cdn.de/images/<format>/assets/v2/img/food/AS_578761334.png'},
#    {'id': '6290726',
#     'name': 'Tomate(n)',
#     'unit': 'kl. Dose/n',
#     'unitId': '104',
#     'amount': 3.0,
#     'isBasic': False,
#     'usageInfo': ', gehackt',
#     'url': 'https://www.chefkoch.de/magazin/artikel/46,0/Chefkoch/Tomaten-Pflanzen-ernten-tolle-Gerichte-entdecken.html',
#     'foodId': '25',
#     'productGroup': 'Obst,  Gemüse und Kräuter',
#     'blsKey': 'G560000',
#     'previewImageUrlTemplate': 'https://img.chefkoch-cdn.de/images/<format>/assets/v2/img/food/AS_70775723.png'},
#    {'id': '6290727',
#     'name': 'Meersalz',
#     'unit': '',
#     'unitId': '9',
#     'amount': 0.0,
#     'isBasic': False,
#     'usageInfo': '',
#     'url': 'https://www.chefkoch.de/magazin/artikel/1054,2/Chefkoch/Salz-unser-wichtigstes-Gewuerz.html',
#     'foodId': '405',
#     'productGroup': 'Salz und Zucker',
#     'blsKey': 'R112000',
#     'previewImageUrlTemplate': 'https://img.chefkoch-cdn.de/images/<format>/assets/v2/img/food/AS_144425698.png'},
#    {'id': '6290728',
#     'name': 'Pfeffer',
#     'unit': '',
#     'unitId': '9',
#     'amount': 0.0,
#     'isBasic': False,
#     'usageInfo': ', frisch gemahlen',
#     'url': None,
#     'foodId': '20',
#     'productGroup': 'Gewürze',
#     'blsKey': 'R258000',
#     'previewImageUrlTemplate': 'https://img.chefkoch-cdn.de/images/<format>/assets/v2/img/food/AS_195161277.png'},
#    {'id': '6290729',
#     'name': 'Möhre(n)',
#     'unit': 'große',
#     'unitId': '21',
#     'amount': 4.0,
#     'isBasic': False,
#     'usageInfo': ', in kleinen Stückchen',
#     'url': 'https://www.chefkoch.de/magazin/artikel/2737,0/Chefkoch/Moehren-knackige-und-gesunde-Wurzeln-fuer-alle-Faelle.html',
#     'foodId': '24',
#     'productGroup': 'Obst,  Gemüse und Kräuter',
#     'blsKey': 'G620100',
#     'previewImageUrlTemplate': 'https://img.chefkoch-cdn.de/images/<format>/assets/v2/img/food/AS_53111552.png'},
#    {'id': '6290730',
#     'name': 'Basilikum',
#     'unit': 'Handvoll',
#     'unitId': '48',
#     'amount': 1.0,
#     'isBasic': False,
#     'usageInfo': '',
#     'url': None,
#     'foodId': '66',
#     'productGroup': 'Obst,  Gemüse und Kräuter',
#     'blsKey': 'G061000',
#     'previewImageUrlTemplate': 'https://img.chefkoch-cdn.de/images/<format>/assets/v2/img/food/US_bLWVqWOUfI4.png'},
#    {'id': '6290731',
#     'name': 'Worcestersauce',
#     'unit': '',
#     'unitId': '9',
#     'amount': 0.0,
#     'isBasic': False,
#     'usageInfo': '',
#     'url': None,
#     'foodId': '10632',
#     'productGroup': 'Essig,  Öl und Soßen',
#     'blsKey': 'R149200',
#     'previewImageUrlTemplate': ''},
#    {'id': '6290732',
#     'name': 'Lorbeerblätter',
#     'unit': '',
#     'unitId': '9',
#     'amount': 1.0,
#     'isBasic': False,
#     'usageInfo': '',
#     'url': None,
#     'foodId': '162',
#     'productGroup': 'Gewürze',
#     'blsKey': 'H120100',
#     'previewImageUrlTemplate': 'https://img.chefkoch-cdn.de/images/<format>/assets/v2/img/food/AS_219962549.png'},
#    {'id': '6290733',
#     'name': 'Oregano',
#     'unit': 'TL, gestr.',
#     'unitId': '164',
#     'amount': 2.0,
#     'isBasic': False,
#     'usageInfo': '',
#     'url': None,
#     'foodId': '457',
#     'productGroup': 'Obst,  Gemüse und Kräuter',
#     'blsKey': 'G076000',
#     'previewImageUrlTemplate': 'https://img.chefkoch-cdn.de/images/<format>/assets/v2/img/food/AS_111141991.png'},
#    {'id': '6290734',
#     'name': 'Tomatenmark',
#     'unit': 'n. B.',
#     'unitId': '7',
#     'amount': 0.0,
#     'isBasic': False,
#     'usageInfo': '',
#     'url': None,
#     'foodId': '80',
#     'productGroup': 'Konserven und Fertiggerichte',
#     'blsKey': 'R160000',
#     'previewImageUrlTemplate': 'https://img.chefkoch-cdn.de/images/<format>/assets/v2/img/food/AS_95095072.png'},
#    {'id': '6290735',
#     'name': 'Spaghetti',
#     'unit': 'kg',
#     'unitId': '28',
#     'amount': 1.0,
#     'isBasic': False,
#     'usageInfo': '',
#     'url': None,
#     'foodId': '6059',
#     'productGroup': 'Nudeln,  Reis & Co.',
#     'blsKey': 'E404000',
#     'previewImageUrlTemplate': 'https://img.chefkoch-cdn.de/images/<format>/assets/v2/img/food/AS_622563903.png'}]}]

# %%
len(s['ingredientGroups'])  # there is only one 'ingredient group' – other recipes might have separate lists for different parts of a dish
# Out:
# 1

# %%
s['ingredientGroups'][0]  # get the first (and only) group
# Out:
# {'header': ' ',
#  'ingredients': [{'id': '6290718',
#    'name': 'Rinderhackfleisch',
#    'unit': 'kg',
#    'unitId': '28',
#    'amount': 1.0,
#    'isBasic': False,
#    'usageInfo': '',
#    'url': None,
#    'foodId': '13796',
#    'productGroup': 'Fleisch und Wurstwaren',
#    'blsKey': 'U010100',
#    'previewImageUrlTemplate': 'https://img.chefkoch-cdn.de/images/<format>/assets/v2/img/food/AS_383250176.png'},
#   {'id': '6290719',
#    'name': 'Speck',
#    'unit': 'g',
#    'unitId': '3',
#    'amount': 250.0,
#    'isBasic': False,
#    'usageInfo': ', in kleinen Würfelchen',
#    'url': None,
#    'foodId': '689',
#    'productGroup': 'Fleisch und Wurstwaren',
#    'blsKey': 'W411000',
#    'previewImageUrlTemplate': 'https://img.chefkoch-cdn.de/images/<format>/assets/v2/img/food/AS_604313966.png'},
#   {'id': '6290720',
#    'name': 'Tomate(n)',
#    'unit': 'Glas',
#    'unitId': '31',
#    'amount': 1.0,
#    'isBasic': False,
#    'usageInfo': ', getrocknete, abgegossen und fein gehackt',
#    'url': 'https://www.chefkoch.de/magazin/artikel/46,0/Chefkoch/Tomaten-Pflanzen-ernten-tolle-Gerichte-entdecken.html',
#    'foodId': '25',
#    'productGroup': 'Obst,  Gemüse und Kräuter',
#    'blsKey': 'G560000',
#    'previewImageUrlTemplate': 'https://img.chefkoch-cdn.de/images/<format>/assets/v2/img/food/AS_70775723.png'},
#   {'id': '6290721',
#    'name': 'Zwiebel(n)',
#    'unit': 'große',
#    'unitId': '21',
#    'amount': 1.0,
#    'isBasic': False,
#    'usageInfo': ', oder 2 kleinere, fein gehackt',
#    'url': None,
#    'foodId': '29',
#    'productGroup': 'Obst,  Gemüse und Kräuter',
#    'blsKey': 'G480000',
#    'previewImageUrlTemplate': 'https://img.chefkoch-cdn.de/images/<format>/assets/v2/img/food/AS_385537967.png'},
#   {'id': '6290722',
#    'name': 'Knoblauchzehe(n)',
#    'unit': '',
#    'unitId': '9',
#    'amount': 3.0,
#    'isBasic': False,
#    'usageInfo': ', fein gehackt',
#    'url': 'https://www.chefkoch.de/magazin/artikel/29,0/Chefkoch/Knoblauch.html',
#    'foodId': '5675',
#    'productGroup': 'Obst,  Gemüse und Kräuter',
#    'blsKey': 'G490000',
#    'previewImageUrlTemplate': 'https://img.chefkoch-cdn.de/images/<format>/assets/v2/img/food/AS_42343143.png'},
#   {'id': '6290723',
#    'name': 'Rosmarin',
#    'unit': 'Handvoll',
#    'unitId': '48',
#    'amount': 1.0,
#    'isBasic': False,
#    'usageInfo': ', die Blätter abgezupft und fein gehackt',
#    'url': None,
#    'foodId': '266',
#    'productGroup': 'Obst,  Gemüse und Kräuter',
#    'blsKey': 'G078000',
#    'previewImageUrlTemplate': 'https://img.chefkoch-cdn.de/images/<format>/assets/v2/img/food/AS_68358825.png'},
#   {'id': '6290724',
#    'name': 'Olivenöl',
#    'unit': '',
#    'unitId': '9',
#    'amount': 0.0,
#    'isBasic': False,
#    'usageInfo': '',
#    'url': 'https://www.chefkoch.de/magazin/artikel/66,0/Chefkoch/Olivenoel-und-die-richtige-Verwendung-in-der-Kueche.html',
#    'foodId': '3393',
#    'productGroup': 'Essig,  Öl und Soßen',
#    'blsKey': 'Q120000',
#    'previewImageUrlTemplate': 'https://img.chefkoch-cdn.de/images/<format>/assets/v2/img/food/AS_124729332.png'},
#   {'id': '6290725',
#    'name': 'Rotwein',
#    'unit': 'Gläser',
#    'unitId': '93',
#    'amount': 2.0,
#    'isBasic': False,
#    'usageInfo': '',
#    'url': None,
#    'foodId': '8793',
#    'productGroup': 'Getränke',
#    'blsKey': 'P200000',
#    'previewImageUrlTemplate': 'https://img.chefkoch-cdn.de/images/<format>/assets/v2/img/food/AS_578761334.png'},
#   {'id': '6290726',
#    'name': 'Tomate(n)',
#    'unit': 'kl. Dose/n',
#    'unitId': '104',
#    'amount': 3.0,
#    'isBasic': False,
#    'usageInfo': ', gehackt',
#    'url': 'https://www.chefkoch.de/magazin/artikel/46,0/Chefkoch/Tomaten-Pflanzen-ernten-tolle-Gerichte-entdecken.html',
#    'foodId': '25',
#    'productGroup': 'Obst,  Gemüse und Kräuter',
#    'blsKey': 'G560000',
#    'previewImageUrlTemplate': 'https://img.chefkoch-cdn.de/images/<format>/assets/v2/img/food/AS_70775723.png'},
#   {'id': '6290727',
#    'name': 'Meersalz',
#    'unit': '',
#    'unitId': '9',
#    'amount': 0.0,
#    'isBasic': False,
#    'usageInfo': '',
#    'url': 'https://www.chefkoch.de/magazin/artikel/1054,2/Chefkoch/Salz-unser-wichtigstes-Gewuerz.html',
#    'foodId': '405',
#    'productGroup': 'Salz und Zucker',
#    'blsKey': 'R112000',
#    'previewImageUrlTemplate': 'https://img.chefkoch-cdn.de/images/<format>/assets/v2/img/food/AS_144425698.png'},
#   {'id': '6290728',
#    'name': 'Pfeffer',
#    'unit': '',
#    'unitId': '9',
#    'amount': 0.0,
#    'isBasic': False,
#    'usageInfo': ', frisch gemahlen',
#    'url': None,
#    'foodId': '20',
#    'productGroup': 'Gewürze',
#    'blsKey': 'R258000',
#    'previewImageUrlTemplate': 'https://img.chefkoch-cdn.de/images/<format>/assets/v2/img/food/AS_195161277.png'},
#   {'id': '6290729',
#    'name': 'Möhre(n)',
#    'unit': 'große',
#    'unitId': '21',
#    'amount': 4.0,
#    'isBasic': False,
#    'usageInfo': ', in kleinen Stückchen',
#    'url': 'https://www.chefkoch.de/magazin/artikel/2737,0/Chefkoch/Moehren-knackige-und-gesunde-Wurzeln-fuer-alle-Faelle.html',
#    'foodId': '24',
#    'productGroup': 'Obst,  Gemüse und Kräuter',
#    'blsKey': 'G620100',
#    'previewImageUrlTemplate': 'https://img.chefkoch-cdn.de/images/<format>/assets/v2/img/food/AS_53111552.png'},
#   {'id': '6290730',
#    'name': 'Basilikum',
#    'unit': 'Handvoll',
#    'unitId': '48',
#    'amount': 1.0,
#    'isBasic': False,
#    'usageInfo': '',
#    'url': None,
#    'foodId': '66',
#    'productGroup': 'Obst,  Gemüse und Kräuter',
#    'blsKey': 'G061000',
#    'previewImageUrlTemplate': 'https://img.chefkoch-cdn.de/images/<format>/assets/v2/img/food/US_bLWVqWOUfI4.png'},
#   {'id': '6290731',
#    'name': 'Worcestersauce',
#    'unit': '',
#    'unitId': '9',
#    'amount': 0.0,
#    'isBasic': False,
#    'usageInfo': '',
#    'url': None,
#    'foodId': '10632',
#    'productGroup': 'Essig,  Öl und Soßen',
#    'blsKey': 'R149200',
#    'previewImageUrlTemplate': ''},
#   {'id': '6290732',
#    'name': 'Lorbeerblätter',
#    'unit': '',
#    'unitId': '9',
#    'amount': 1.0,
#    'isBasic': False,
#    'usageInfo': '',
#    'url': None,
#    'foodId': '162',
#    'productGroup': 'Gewürze',
#    'blsKey': 'H120100',
#    'previewImageUrlTemplate': 'https://img.chefkoch-cdn.de/images/<format>/assets/v2/img/food/AS_219962549.png'},
#   {'id': '6290733',
#    'name': 'Oregano',
#    'unit': 'TL, gestr.',
#    'unitId': '164',
#    'amount': 2.0,
#    'isBasic': False,
#    'usageInfo': '',
#    'url': None,
#    'foodId': '457',
#    'productGroup': 'Obst,  Gemüse und Kräuter',
#    'blsKey': 'G076000',
#    'previewImageUrlTemplate': 'https://img.chefkoch-cdn.de/images/<format>/assets/v2/img/food/AS_111141991.png'},
#   {'id': '6290734',
#    'name': 'Tomatenmark',
#    'unit': 'n. B.',
#    'unitId': '7',
#    'amount': 0.0,
#    'isBasic': False,
#    'usageInfo': '',
#    'url': None,
#    'foodId': '80',
#    'productGroup': 'Konserven und Fertiggerichte',
#    'blsKey': 'R160000',
#    'previewImageUrlTemplate': 'https://img.chefkoch-cdn.de/images/<format>/assets/v2/img/food/AS_95095072.png'},
#   {'id': '6290735',
#    'name': 'Spaghetti',
#    'unit': 'kg',
#    'unitId': '28',
#    'amount': 1.0,
#    'isBasic': False,
#    'usageInfo': '',
#    'url': None,
#    'foodId': '6059',
#    'productGroup': 'Nudeln,  Reis & Co.',
#    'blsKey': 'E404000',
#    'previewImageUrlTemplate': 'https://img.chefkoch-cdn.de/images/<format>/assets/v2/img/food/AS_622563903.png'}]}

# %%
s['ingredientGroups'][0]['ingredients']  # get the ingredients list
# Out:
# [{'id': '6290718',
#   'name': 'Rinderhackfleisch',
#   'unit': 'kg',
#   'unitId': '28',
#   'amount': 1.0,
#   'isBasic': False,
#   'usageInfo': '',
#   'url': None,
#   'foodId': '13796',
#   'productGroup': 'Fleisch und Wurstwaren',
#   'blsKey': 'U010100',
#   'previewImageUrlTemplate': 'https://img.chefkoch-cdn.de/images/<format>/assets/v2/img/food/AS_383250176.png'},
#  {'id': '6290719',
#   'name': 'Speck',
#   'unit': 'g',
#   'unitId': '3',
#   'amount': 250.0,
#   'isBasic': False,
#   'usageInfo': ', in kleinen Würfelchen',
#   'url': None,
#   'foodId': '689',
#   'productGroup': 'Fleisch und Wurstwaren',
#   'blsKey': 'W411000',
#   'previewImageUrlTemplate': 'https://img.chefkoch-cdn.de/images/<format>/assets/v2/img/food/AS_604313966.png'},
#  {'id': '6290720',
#   'name': 'Tomate(n)',
#   'unit': 'Glas',
#   'unitId': '31',
#   'amount': 1.0,
#   'isBasic': False,
#   'usageInfo': ', getrocknete, abgegossen und fein gehackt',
#   'url': 'https://www.chefkoch.de/magazin/artikel/46,0/Chefkoch/Tomaten-Pflanzen-ernten-tolle-Gerichte-entdecken.html',
#   'foodId': '25',
#   'productGroup': 'Obst,  Gemüse und Kräuter',
#   'blsKey': 'G560000',
#   'previewImageUrlTemplate': 'https://img.chefkoch-cdn.de/images/<format>/assets/v2/img/food/AS_70775723.png'},
#  {'id': '6290721',
#   'name': 'Zwiebel(n)',
#   'unit': 'große',
#   'unitId': '21',
#   'amount': 1.0,
#   'isBasic': False,
#   'usageInfo': ', oder 2 kleinere, fein gehackt',
#   'url': None,
#   'foodId': '29',
#   'productGroup': 'Obst,  Gemüse und Kräuter',
#   'blsKey': 'G480000',
#   'previewImageUrlTemplate': 'https://img.chefkoch-cdn.de/images/<format>/assets/v2/img/food/AS_385537967.png'},
#  {'id': '6290722',
#   'name': 'Knoblauchzehe(n)',
#   'unit': '',
#   'unitId': '9',
#   'amount': 3.0,
#   'isBasic': False,
#   'usageInfo': ', fein gehackt',
#   'url': 'https://www.chefkoch.de/magazin/artikel/29,0/Chefkoch/Knoblauch.html',
#   'foodId': '5675',
#   'productGroup': 'Obst,  Gemüse und Kräuter',
#   'blsKey': 'G490000',
#   'previewImageUrlTemplate': 'https://img.chefkoch-cdn.de/images/<format>/assets/v2/img/food/AS_42343143.png'},
#  {'id': '6290723',
#   'name': 'Rosmarin',
#   'unit': 'Handvoll',
#   'unitId': '48',
#   'amount': 1.0,
#   'isBasic': False,
#   'usageInfo': ', die Blätter abgezupft und fein gehackt',
#   'url': None,
#   'foodId': '266',
#   'productGroup': 'Obst,  Gemüse und Kräuter',
#   'blsKey': 'G078000',
#   'previewImageUrlTemplate': 'https://img.chefkoch-cdn.de/images/<format>/assets/v2/img/food/AS_68358825.png'},
#  {'id': '6290724',
#   'name': 'Olivenöl',
#   'unit': '',
#   'unitId': '9',
#   'amount': 0.0,
#   'isBasic': False,
#   'usageInfo': '',
#   'url': 'https://www.chefkoch.de/magazin/artikel/66,0/Chefkoch/Olivenoel-und-die-richtige-Verwendung-in-der-Kueche.html',
#   'foodId': '3393',
#   'productGroup': 'Essig,  Öl und Soßen',
#   'blsKey': 'Q120000',
#   'previewImageUrlTemplate': 'https://img.chefkoch-cdn.de/images/<format>/assets/v2/img/food/AS_124729332.png'},
#  {'id': '6290725',
#   'name': 'Rotwein',
#   'unit': 'Gläser',
#   'unitId': '93',
#   'amount': 2.0,
#   'isBasic': False,
#   'usageInfo': '',
#   'url': None,
#   'foodId': '8793',
#   'productGroup': 'Getränke',
#   'blsKey': 'P200000',
#   'previewImageUrlTemplate': 'https://img.chefkoch-cdn.de/images/<format>/assets/v2/img/food/AS_578761334.png'},
#  {'id': '6290726',
#   'name': 'Tomate(n)',
#   'unit': 'kl. Dose/n',
#   'unitId': '104',
#   'amount': 3.0,
#   'isBasic': False,
#   'usageInfo': ', gehackt',
#   'url': 'https://www.chefkoch.de/magazin/artikel/46,0/Chefkoch/Tomaten-Pflanzen-ernten-tolle-Gerichte-entdecken.html',
#   'foodId': '25',
#   'productGroup': 'Obst,  Gemüse und Kräuter',
#   'blsKey': 'G560000',
#   'previewImageUrlTemplate': 'https://img.chefkoch-cdn.de/images/<format>/assets/v2/img/food/AS_70775723.png'},
#  {'id': '6290727',
#   'name': 'Meersalz',
#   'unit': '',
#   'unitId': '9',
#   'amount': 0.0,
#   'isBasic': False,
#   'usageInfo': '',
#   'url': 'https://www.chefkoch.de/magazin/artikel/1054,2/Chefkoch/Salz-unser-wichtigstes-Gewuerz.html',
#   'foodId': '405',
#   'productGroup': 'Salz und Zucker',
#   'blsKey': 'R112000',
#   'previewImageUrlTemplate': 'https://img.chefkoch-cdn.de/images/<format>/assets/v2/img/food/AS_144425698.png'},
#  {'id': '6290728',
#   'name': 'Pfeffer',
#   'unit': '',
#   'unitId': '9',
#   'amount': 0.0,
#   'isBasic': False,
#   'usageInfo': ', frisch gemahlen',
#   'url': None,
#   'foodId': '20',
#   'productGroup': 'Gewürze',
#   'blsKey': 'R258000',
#   'previewImageUrlTemplate': 'https://img.chefkoch-cdn.de/images/<format>/assets/v2/img/food/AS_195161277.png'},
#  {'id': '6290729',
#   'name': 'Möhre(n)',
#   'unit': 'große',
#   'unitId': '21',
#   'amount': 4.0,
#   'isBasic': False,
#   'usageInfo': ', in kleinen Stückchen',
#   'url': 'https://www.chefkoch.de/magazin/artikel/2737,0/Chefkoch/Moehren-knackige-und-gesunde-Wurzeln-fuer-alle-Faelle.html',
#   'foodId': '24',
#   'productGroup': 'Obst,  Gemüse und Kräuter',
#   'blsKey': 'G620100',
#   'previewImageUrlTemplate': 'https://img.chefkoch-cdn.de/images/<format>/assets/v2/img/food/AS_53111552.png'},
#  {'id': '6290730',
#   'name': 'Basilikum',
#   'unit': 'Handvoll',
#   'unitId': '48',
#   'amount': 1.0,
#   'isBasic': False,
#   'usageInfo': '',
#   'url': None,
#   'foodId': '66',
#   'productGroup': 'Obst,  Gemüse und Kräuter',
#   'blsKey': 'G061000',
#   'previewImageUrlTemplate': 'https://img.chefkoch-cdn.de/images/<format>/assets/v2/img/food/US_bLWVqWOUfI4.png'},
#  {'id': '6290731',
#   'name': 'Worcestersauce',
#   'unit': '',
#   'unitId': '9',
#   'amount': 0.0,
#   'isBasic': False,
#   'usageInfo': '',
#   'url': None,
#   'foodId': '10632',
#   'productGroup': 'Essig,  Öl und Soßen',
#   'blsKey': 'R149200',
#   'previewImageUrlTemplate': ''},
#  {'id': '6290732',
#   'name': 'Lorbeerblätter',
#   'unit': '',
#   'unitId': '9',
#   'amount': 1.0,
#   'isBasic': False,
#   'usageInfo': '',
#   'url': None,
#   'foodId': '162',
#   'productGroup': 'Gewürze',
#   'blsKey': 'H120100',
#   'previewImageUrlTemplate': 'https://img.chefkoch-cdn.de/images/<format>/assets/v2/img/food/AS_219962549.png'},
#  {'id': '6290733',
#   'name': 'Oregano',
#   'unit': 'TL, gestr.',
#   'unitId': '164',
#   'amount': 2.0,
#   'isBasic': False,
#   'usageInfo': '',
#   'url': None,
#   'foodId': '457',
#   'productGroup': 'Obst,  Gemüse und Kräuter',
#   'blsKey': 'G076000',
#   'previewImageUrlTemplate': 'https://img.chefkoch-cdn.de/images/<format>/assets/v2/img/food/AS_111141991.png'},
#  {'id': '6290734',
#   'name': 'Tomatenmark',
#   'unit': 'n. B.',
#   'unitId': '7',
#   'amount': 0.0,
#   'isBasic': False,
#   'usageInfo': '',
#   'url': None,
#   'foodId': '80',
#   'productGroup': 'Konserven und Fertiggerichte',
#   'blsKey': 'R160000',
#   'previewImageUrlTemplate': 'https://img.chefkoch-cdn.de/images/<format>/assets/v2/img/food/AS_95095072.png'},
#  {'id': '6290735',
#   'name': 'Spaghetti',
#   'unit': 'kg',
#   'unitId': '28',
#   'amount': 1.0,
#   'isBasic': False,
#   'usageInfo': '',
#   'url': None,
#   'foodId': '6059',
#   'productGroup': 'Nudeln,  Reis & Co.',
#   'blsKey': 'E404000',
#   'previewImageUrlTemplate': 'https://img.chefkoch-cdn.de/images/<format>/assets/v2/img/food/AS_622563903.png'}]

# %%
ids = [1618631269095146, 1738671282836420]  # the recipes we're interested in

shopping_list = {}  # preparing to add items

# add everything to the shopping list
for idn in ids:
    api_url = "https://api.chefkoch.de/v2/recipes/" + str(idn)
    
    result = requests.get(api_url).json()
    
    # there might be multiple ingredient groups (e.g. a cakes has dough + filling)
    for group in result['ingredientGroups']:

        # add one ingredient after another
        for ingredient in group['ingredients']:
            name = ingredient["name"]
            unit = ingredient["unit"]
            amount = ingredient["amount"]
            
            # if an ingredient is not on the shopping list yet, add it with an empty list for amounts
            # note that we do not match ingredients that have different names but mean the same thing
            # we also do not match quantities, just add them to a list for each ingredient
            if name not in shopping_list: 
                shopping_list[name] = []
            
            shopping_list[name].append((unit,amount))

# %%
shopping_list
# Out:
# {'Rinderhackfleisch': [('kg', 1.0)],
#  'Speck': [('g', 250.0)],
#  'Tomate(n)': [('Glas', 1.0), ('kl. Dose/n', 3.0)],
#  'Zwiebel(n)': [('große', 1.0), ('kleine', 1.0)],
#  'Knoblauchzehe(n)': [('', 3.0)],
#  'Rosmarin': [('Handvoll', 1.0)],
#  'Olivenöl': [('', 0.0)],
#  'Rotwein': [('Gläser', 2.0)],
#  'Meersalz': [('', 0.0)],
#  'Pfeffer': [('', 0.0)],
#  'Möhre(n)': [('große', 4.0)],
#  'Basilikum': [('Handvoll', 1.0)],
#  'Worcestersauce': [('', 0.0)],
#  'Lorbeerblätter': [('', 1.0)],
#  'Oregano': [('TL, gestr.', 2.0)],
#  'Tomatenmark': [('n. B.', 0.0)],
#  'Spaghetti': [('kg', 1.0)],
#  'Hackfleisch, gemischtes': [('g', 500.0)],
#  'Öl zum Braten': [('etwas', 0.0)],
#  'Erbsen und Möhren': [('kl. Dose/n', 1.0)],
#  'Fleischbrühe': [('ml', 300.0)],
#  'Sahne': [('ml', 200.0)],
#  'Salz und Pfeffer': [('n. B.', 0.0)],
#  'Paprikapulver': [('n. B.', 0.0)],
#  'Schnittlauch': [('n. B.', 0.0)],
#  'Petersilie': [('n. B.', 0.0)],
#  'Saucenbinder': [('evtl.', 0.0)]}

# %% [markdown]
# ## List Uni Mannheim's research affiliations
#
# Create a Pandas DataFrame that contains all research centers listed here: https://www.uni-mannheim.de/en/research/our-research/research-institutions/ with name and URL.

# %%
from bs4 import BeautifulSoup

result = requests.get('https://www.uni-mannheim.de/en/research/our-research/research-institutions/')
result.text
# Out:
# '<!DOCTYPE html>\n<html class="no-js" lang="en">\n<head>\n\n<meta charset="utf-8">\n<!-- \n\tThis website is powered by TYPO3 - inspiring people to share!\n\tTYPO3 is a free open source Content Management Framework initially created by Kasper Skaarhoj and licensed under GNU/GPL.\n\tTYPO3 is copyright 1998-2023 of Kasper Skaarhoj. Extensions are copyright of their respective owners.\n\tInformation and contribution at https://typo3.org/\n-->\n\n\n\n<title>Research Institutions | University of Mannheim</title>\n<meta name="generator" content="TYPO3 CMS">\n<meta name="twitter:card" content="summary">\n<meta name="revisit-after" content="10 days"><link rel="stylesheet" href="/typo3temp/assets/css/dc656ab57dc88c3dbbc4ad4edaac25e3.1697182786.css" media="all"><link rel="stylesheet" href="/typo3conf/ext/uma_site/Resources/Public/Icons/sprite.1697182548.css" media="all"><link rel="stylesheet" href="/typo3conf/ext/uma_site/Vendor/maplibre-gl/css/mapbox-gl.1696926849.css" media="all"><link rel="stylesheet" href="/typo3conf/ext/uma_site/Resources/Public/Css/app.1697194816.css" media="all"><link rel="stylesheet" href="/typo3conf/ext/uma_site/Resources/Public/Css/print.1697182522.css" media="print"><meta property="og:url" content="https://www.uni-mannheim.de/en/research/our-research/research-institutions/"><meta property="og:site_name" content=""><meta property="og:title" content="Research Institutions | University of Mannheim"><meta property="og:description" content=""><meta property="og:type" content="website">      <meta http-equiv="X-UA-Compatible" content="IE=edge">\n      <meta name="viewport" content="width=device-width, initial-scale=1.0, minimum-scale=1.0"><link rel="icon" type="image/x-icon" href="/typo3conf/ext/uma_site/Resources/Public/Images/Favicons/favicon.ico"><link rel="icon" type="image/png" sizes="16x16" href="/typo3conf/ext/uma_site/Resources/Public/Images/Favicons/favicon-16x16.png"><link rel="icon" type="image/png" sizes="32x32" href="/typo3conf/ext/uma_site/Resources/Public/Images/Favicons/favicon-32x32.png"><link rel="apple-touch-icon" sizes="180x180" href="/typo3conf/ext/uma_site/Resources/Public/Images/Favicons/apple-touch-icon.png?v=2"><link rel="alternate" type="application/rss+xml" title="Aktuelle News der Universität Mannheim" href="https://www.uni-mannheim.de/en/newsroom/news/rss.xml"><link rel="alternate" type="application/rss+xml" title="Aktuelle Events der Universität Mannheim" href="https://www.uni-mannheim.de/en/newsroom/events/rss.xml"><!-- Matomo -->\n<script>\n  var _paq = _paq || [];\n  var siteIds = [92];\n  _paq.push([\'requireConsent\']);\n  _paq.push([\'trackPageView\']);\n  _paq.push([\'enableLinkTracking\']);\n</script>\n<!-- End Matomo Code --><link rel="canonical" href="https://www.uni-mannheim.de/en/research/our-research/research-institutions/"><link rel="alternate" hreflang="de-DE" href="https://www.uni-mannheim.de/forschung/forschungsprofil/forschungseinrichtungen/"><link rel="alternate" hreflang="en-US" href="https://www.uni-mannheim.de/en/research/our-research/research-institutions/"><link rel="alternate" hreflang="x-default" href="https://www.uni-mannheim.de/forschung/forschungsprofil/forschungseinrichtungen/"><!-- This site is optimized with the Yoast SEO for TYPO3 plugin - https://yoast.com/typo3-extensions-seo/ -->\n<script type="application/ld+json">[{"@context":"https:\\/\\/www.schema.org","@type":"BreadcrumbList","itemListElement":[{"@type":"ListItem","position":1,"item":{"@id":"https:\\/\\/www.uni-mannheim.de\\/en\\/","name":"University of Mannheim"}},{"@type":"ListItem","position":2,"item":{"@id":"https:\\/\\/www.uni-mannheim.de\\/en\\/research\\/","name":"Research"}},{"@type":"ListItem","position":3,"item":{"@id":"https:\\/\\/www.uni-mannheim.de\\/en\\/research\\/our-research\\/","name":"Our Research"}},{"@type":"ListItem","position":4,"item":{"@id":"https:\\/\\/www.uni-mannheim.de\\/en\\/research\\/our-research\\/research-institutions\\/","name":"Research Institutions"}}]}]</scr ...

# %%
soup = BeautifulSoup(result.text)
soup.select('div.uma-dict-entry')  # note that not all entries have a link
# Out:
# [<div class="uma-dict-entry" data-entry="Center for Corporate Succession" data-keywords=""><a href="http://www.zentuma.de/" rel="noreferrer" target="_blank">Center for Corporate Succession</a></div>,
#  <div class="uma-dict-entry" data-entry="Center for Insolvency and Reorganization" data-keywords=""><a href="http://www.zis.uni-mannheim.de/" rel="noreferrer" target="_blank">Center for Insolvency and Reorganization</a></div>,
#  <div class="uma-dict-entry" data-entry="Center for Teacher Education and Innovation" data-keywords="">Center for Teacher Education and Innovation</div>,
#  <div class="uma-dict-entry" data-entry="Center of Econometrics and Empirical Economics (CEEE)" data-keywords=""><a href="http://ceee-mannheim.de/" rel="noreferrer" target="_blank">Center of Econometrics and Empirical Economics (CEEE)</a></div>,
#  <div class="uma-dict-entry" data-entry="Centre for European Economic Research" data-keywords=""><a href="http://www.zew.de/de/" rel="noreferrer" target="_blank">Centre for European Economic Research</a></div>,
#  <div class="uma-dict-entry" data-entry="Collaborative Research Center (CRC) TR 224 - EPoS" data-keywords=""><a href="https://www.crctr224.de/" rel="noreferrer" target="_blank">Collaborative Research Center (CRC) TR 224 – EPoS</a></div>,
#  <div class="uma-dict-entry" data-entry="Collaborative Research Center SFB 884 " data-keywords="" economy="" of="" political="" reforms=""><a href="https://www.uni-mannheim.de/reforms/" target="_top">Collaborative Research Center SFB 884 “Political Economy of Reforms”</a></div>,
#  <div class="uma-dict-entry" data-entry="DFG Research Training Group " data-keywords="" in="" modeling="" psychology="" statistical=""><a href="http://smip.uni-mannheim.de/" rel="noreferrer" target="_blank">DFG Research Training Group “Statistical Modeling in Psychology” (SMiP)</a></div>,
#  <div and="" class="uma-dict-entry" complex="" data-entry="DFG Research Training Group: " data-keywords="" modelling="" of="" processes="" statistical="" systems=""><a href="http://rtg1953.uni-heidelberg.uni-mannheim.de/" rel="noreferrer" target="_blank">DFG Research Training Group: “Statistical Modelling of Complex Systems and Processes”</a></div>,
#  <div class="uma-dict-entry" data-entry="GESIS - Leibniz Institute for the Social Sciences" data-keywords=""><a href="https://www.gesis.org/home/" rel="noreferrer" target="_blank">GESIS – Leibniz Institute for the Social Sciences</a></div>,
#  <div class="uma-dict-entry" data-entry="Graduate School of Economic and Social Sciences (GESS)" data-keywords=""><a href="https://gess.uni-mannheim.de/" rel="noreferrer" target="_blank">Graduate School of Economic and Social Sciences (GESS)</a></div>,
#  <div class="uma-dict-entry" data-entry="Institute for Enterprise Systems (InES)" data-keywords=""><a href="http://www.institute-for-enterprise-systems.de/" rel="noreferrer" target="_blank">Institute for Enterprise Systems (InES)</a></div>,
#  <div class="uma-dict-entry" data-entry="Institute for German and International Transport Law" data-keywords=""><a href="http://www.transportrecht.uni-mannheim.de/" rel="noreferrer" target="_blank">Institute for German and International Transport Law</a></div>,
#  <div class="uma-dict-entry" data-entry="Institute for German, European and International Medical Law, Public Health Law and Bioethics (IMGB)" data-keywords=""><a href="http://www.imgb.de/" target="_blank">Institute for German, European and International Medical Law, Public Health Law and Bioethics (IMGB)</a></div>,
#  <div class="uma-dict-entry" data-entry="Institute for Market-Oriented Management (IMU)" data-keywords="">Institute for Market-Oriented Management (IMU)</div>,
#  <div class="uma-dict-entry" data-entry="Institute of Insurance Sciences" data-keywords="">Institute of Insurance Sciences</div>,
#  <div class="uma-dict-entry" data-entry="Interdisciplinary Center for Intellectual Property" data-keywords=""><a href="http://izg-mannheim.de/" rel="noreferrer" target="_blank">Interdisciplinary Center for Intellectual Property</a></div>,
#  <div class="uma-dict-entry" data-entry="Leibniz ScienceCampus " data-keywords="" mannheim="" taxation=""><a href="https://www.mannheimtaxation.eu/mannheim-taxation/home" rel="noreferrer" target="_blank">Leibniz ScienceCampus “Mannheim Taxation”</a></div>,
#  <div class="uma-dict-entry" data-entry="Leibniz-Institut für Deutsche Sprache (IDS)" data-keywords=""><a href="http://www1.ids-mannheim.de/" rel="noreferrer" target="_blank">Leibniz-Institut für Deutsche Sprache (IDS)</a></div>,
#  <div class="uma-dict-entry" data-entry="Mannheim Center for Empirical Research on Multilingualism" data-keywords=""><a href="http://www.mazem.de/" rel="noreferrer" target="_blank">Mannheim Center for Empirical Research on Multilingualism</a></div>,
#  <div class="uma-dict-entry" data-entry="Mannheim Center for Entrepreneurship and Innovation (MCEI)" data-keywords=""><a href="https://www.mcei.de/">Mannheim Center for Entrepreneurship and Innovation (MCEI)</a></div>,
#  <div class="uma-dict-entry" data-entry="Mannheim Centre for Competition and Innovation (MaCCI)" data-keywords=""><a href="http://www.macci-mannheim.eu/macci-mannheim-centre-for-competition-and-innovation/home.html" rel="noreferrer" target="_blank">Mannheim Centre for Competition and Innovation (MaCCI)</a></div>,
#  <div class="uma-dict-entry" data-entry="Mannheim Centre for European Social Research" data-keywords=""><a href="/en/mannheim-centre-for-european-social-research-mzes/">Mannheim Centre for European Social Research</a></div>,
#  <div class="uma-dict-entry" data-entry="Mannheim Institute for Financial Education (MIFE)" data-keywords=""><a href="/en/mife/" target="_blank">Mannheim Institute for Financial Education (MIFE)</a></div>,
#  <div class="uma-dict-entry" data-entry="Mannheim Institute for Sustainable Energy Studies (MISES)" data-keywords=""><a href="/en/mises/">Mannheim Institute for Sustainable Energy Studies (MISES)</a></div>,
#  <div class="uma-dict-entry" data-entry="Otto Selz Institute for Applied Psychology (OSI)" data-keywords=""><a href="/en/osi/" target="_blank">Otto Selz Institute for Applied Psychology (OSI)</a></div>,
#  <div class="uma-dict-entry" data-entry="TRR 266 Accounting for Transparency" data-keywords="">TRR 266 Accounting for Transparency</div>]

# %%
import pandas as pd

affiliations = []  # prepare an empty list for the research centers

for institution in soup.select('div.uma-dict-entry'):
    name = institution.text  # the text that is left after stripping all tags

    link = None
    anchors = institution.select('a')
    
    # if there's an anchor element, get where it links to
    if len(anchors) > 0:
        link = anchors[0]['href']

        # convert relative to absolute links
        if not(link.startswith('https:/')) and not(link.startswith('http:/')):
            link = 'https://www.uni-mannheim.de' + link
    
    affiliations.append({'name': name, 'link': link})

pd.DataFrame(affiliations)
# Out:
#                                                  name  \
# 0                     Center for Corporate Succession
# 1            Center for Insolvency and Reorganization
# 2         Center for Teacher Education and Innovation
# 3   Center of Econometrics and Empirical Economics...
# 4               Centre for European Economic Research
# 5   Collaborative Research Center (CRC) TR 224 – EPoS
# 6   Collaborative Research Center SFB 884 “Politic...
# 7   DFG Research Training Group “Statistical Model...
# 8   DFG Research Training Group: “Statistical Mode...
# 9   GESIS – Leibniz Institute for the Social Sciences
# 10  Graduate School of Economic and Social Science...
# 11            Institute for Enterprise Systems (InES)
# 12  Institute for German and International Transpo...
# 13  Institute for German, European and Internation...
# 14     Institute for Market-Oriented Management (IMU)
# 15                    Institute of Insurance Sciences
# 16  Interdisciplinary Center for Intellectual Prop...
# 17          Leibniz ScienceCampus “Mannheim Taxation”
# 18        Leibniz-Institut für Deutsche Sprache (IDS)
# 19  Mannheim Center for Empirical Research on Mult...
# 20  Mannheim Center for Entrepreneurship and Innov...
# 21  Mannheim Centre for Competition and Innovation...
# 22       Mannheim Centre for European Social Research
# 23  Mannheim Institute for Financial Education (MIFE)
# 24  Mannheim Institute for Sustainable Energy Stud...
# 25   Otto Selz Institute for Applied Psychology (OSI)
# 26                TRR 266 Accounting for Transparency
#
#                                                  link
# 0                              http://www.zentuma.de/
# 1                     http://www.zis.uni-mannheim.de/
# 2                                                None
# 3                            http://ceee-mannheim.de/
# 4                               http://www.zew.de/de/
# 5                            https://www.crctr224.de/
# 6                https://www.uni-mannheim.de/reforms/
# 7                        http://smip.uni-mannheim.de/
# 8      http://rtg1953.uni-heidelberg.uni-mannheim.de/
# 9                         https://www.gesis.org/home/
# 10                      https://gess.uni-mannheim.de/
# 11    http://www.institute-for-enterprise-systems.de/
# 12         http://www.transportrecht.uni-mannheim.de/
# 13                                http://www.imgb.de/
# 14                                               None
# 15                                               None
# 16                            http://izg-mannheim.de/
# 17  https://www.mannheimtaxation.eu/mannheim-taxat...
# 18                       http://www1.ids-mannheim.de/
# 19                               http://www.mazem.de/
# 20                               https://www.mcei.de/
# 21  http://www.macci-mannheim.eu/macci-mannheim-ce...
# 22  https://www.uni-mannheim.de/en/mannheim-centre...
# 23               https://www.uni-mannheim.de/en/mife/
# 24              https://www.uni-mannheim.de/en/mises/
# 25                https://www.uni-mannheim.de/en/osi/
# 26                                               None

# %% [markdown]
# ## Extract the table of soccer results (Bundesliga) from the "sportschau" website https://www.sportschau.de/live-und-ergebnisse/fussball/deutschland-bundesliga/tabelle/

# %%
import pandas as pd

page = requests.get("https://www.sportschau.de/live-und-ergebnisse/fussball/deutschland-bundesliga/tabelle/")
tables = pd.read_html(page.content)

# %%
current_table = tables[0]  # get the content of the first (and only) table

# %%
current_table
# Out:
#     Unnamed: 0   #  Unnamed: 2             Mannschaft  Mannschaft.1  \
# 0          NaN   1         NaN       Bayer Leverkusen    Leverkusen
# 1          NaN   2         NaN          VfB Stuttgart     Stuttgart
# 2          NaN   3         NaN         Bayern München        Bayern
# 3          NaN   4         NaN      Borussia Dortmund      Dortmund
# 4          NaN   5         NaN        1899 Hoffenheim    Hoffenheim
# 5          NaN   6         NaN             RB Leipzig       Leipzig
# 6          NaN   7         NaN          VfL Wolfsburg     Wolfsburg
# 7          NaN   8         NaN    Eintracht Frankfurt  E. Frankfurt
# 8          NaN   9         NaN            SC Freiburg      Freiburg
# 9          NaN  10         NaN  1. FC Heidenheim 1846    Heidenheim
# 10         NaN  11         NaN        SV Darmstadt 98     Darmstadt
# 11         NaN  12         NaN   Bor. Mönchengladbach    M'gladbach
# 12         NaN  13         NaN     1. FC Union Berlin  Union Berlin
# 13         NaN  14         NaN          Werder Bremen        Werder
# 14         NaN  15         NaN            FC Augsburg      Augsburg
# 15         NaN  16         NaN             VfL Bochum        Bochum
# 16         NaN  17         NaN        1. FSV Mainz 05         Mainz
# 17         NaN  18         NaN             1. FC Köln          Köln
#
#    Mannschaft.2  Sp.  S  U  N   Tore  Diff.  Pkt.
# 0           B04    7  6  1  0   23:6     17    19
# 1           VFB    7  6  0  1   22:8     14    18
# 2           FCB    7  5  2  0   23:6     17    17
# 3           BVB    7  5  2  0   16:8      8    17
# 4           TSG    7  5  0  2  16:11      5    15
# 5           RBL    7  4  2  1   16:6     10    14
# 6           WOB    7  4  0  3   10:9      1    12
# 7           SGE    7  2  4  1    6:5      1    10
# 8           SCF    7  3  1  3   7:13     -6    10
# 9           HDH    7  2  1  4  10:15     -5     7
# 10          D98    7  2  1  4  12:19     -7     7
# 11          BMG    7  1  3  3  13:16     -3     6
# 12          FCU    7  2  0  5  11:14     -3     6
# 13          SVW    7  2  0  5  12:17     -5     6
# 14          FCA    7  1  2  4  10:17     -7     5
# 15          BOC    7  0  4  3   5:19    -14     4
# 16          M05    7  0  2  5   6:19    -13     2
# 17          KOE    7  0  1  6   4:14    -10     1

# %%
current_table.drop(['Unnamed: 0', 'Unnamed: 2'], axis = 1)  # remove unnamed columns
# Out:
#      #             Mannschaft  Mannschaft.1 Mannschaft.2  Sp.  S  U  N   Tore  \
# 0    1       Bayer Leverkusen    Leverkusen          B04    7  6  1  0   23:6
# 1    2          VfB Stuttgart     Stuttgart          VFB    7  6  0  1   22:8
# 2    3         Bayern München        Bayern          FCB    7  5  2  0   23:6
# 3    4      Borussia Dortmund      Dortmund          BVB    7  5  2  0   16:8
# 4    5        1899 Hoffenheim    Hoffenheim          TSG    7  5  0  2  16:11
# 5    6             RB Leipzig       Leipzig          RBL    7  4  2  1   16:6
# 6    7          VfL Wolfsburg     Wolfsburg          WOB    7  4  0  3   10:9
# 7    8    Eintracht Frankfurt  E. Frankfurt          SGE    7  2  4  1    6:5
# 8    9            SC Freiburg      Freiburg          SCF    7  3  1  3   7:13
# 9   10  1. FC Heidenheim 1846    Heidenheim          HDH    7  2  1  4  10:15
# 10  11        SV Darmstadt 98     Darmstadt          D98    7  2  1  4  12:19
# 11  12   Bor. Mönchengladbach    M'gladbach          BMG    7  1  3  3  13:16
# 12  13     1. FC Union Berlin  Union Berlin          FCU    7  2  0  5  11:14
# 13  14          Werder Bremen        Werder          SVW    7  2  0  5  12:17
# 14  15            FC Augsburg      Augsburg          FCA    7  1  2  4  10:17
# 15  16             VfL Bochum        Bochum          BOC    7  0  4  3   5:19
# 16  17        1. FSV Mainz 05         Mainz          M05    7  0  2  5   6:19
# 17  18             1. FC Köln          Köln          KOE    7  0  1  6   4:14
#
#     Diff.  Pkt.
# 0      17    19
# 1      14    18
# 2      17    17
# 3       8    17
# 4       5    15
# 5      10    14
# 6       1    12
# 7       1    10
# 8      -6    10
# 9      -5     7
# 10     -7     7
# 11     -3     6
# 12     -3     6
# 13     -5     6
# 14     -7     5
# 15    -14     4
# 16    -13     2
# 17    -10     1
