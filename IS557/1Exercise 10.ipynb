# %% [markdown]
# Today we will be exploring **The Titanic dataset** which is commonly used in introductory Machine Learning classes.
# It contains data for 887 passengers on the Titanic. Each row represents one person. The columns describe different attributes about the person including whether they survived, their age, their on-board class, their sex, and the fare they paid.
# This dataset is already included to seaborn package

# %%
import seaborn as sns
sns.set_theme()
titanic = sns.load_dataset('titanic');
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic['survived'].astype('category')
titanic['class'].astype('category')
titanic['adult_male'].astype('category')
titanic['embark_town'].astype('category')
titanic['alive'].astype('category')
titanic['embarked'].astype('category')
titanic['sex'].astype('category')
# Out:
# 0        male
# 1      female
# 2      female
# 3      female
# 4        male
#         ...
# 886      male
# 887    female
# 888    female
# 889      male
# 890      male
# Name: sex, Length: 891, dtype: category
# Categories (2, object): ['female', 'male']

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %% [markdown]
# # For the three tasks below try to use as many vizualization as possible

# %% [markdown]
# ## Plot the distribution of passengers age and fare

# %%
sns.relplot(titanic, x = 'age', y = 'fare', hue = 'sex')

# %%
sns.catplot(titanic, y = 'age',x = 'fare', kind = 'strip')

# %% [markdown]
# ## Check how these distributions vary depending on gender of passengers

# %%
sns.relplot(titanic, x = 'age', y = 'fare', hue = 'sex', kind = 'line')

# %%
sns.lmplot(titanic, x = 'age', y = 'fare', hue = 'sex')

# %%
sns.displot(titanic, x = 'age', y = 'fare', hue = 'class', kind = 'kde', fill = True)

# %% [markdown]
# ## Check how these distributions vary depending on the class variable

# %%
selected_columns = titanic[['age', 'fare', 'class']]

sns.pairplot(selected_columns, hue = 'class', corner = True)

# %% [markdown]
# # Visually explore the dataset and try to find what variables are closely related to survival chance. What criteria might be used to classify passengers as alive or not?

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
sc = titanic[['survived', 'sex',	'age', 'fare',	'embarked', 'class', 'adult_male',	'deck',	'embark_town',	'alone']]
sns.pairplot(sc, hue = 'survived', corner = True)
